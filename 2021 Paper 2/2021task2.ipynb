# %% [markdown]
# **2**&nbsp;&nbsp;&nbsp;For this question you are provided with three text files, each contains a valid list of positive integers, one per line:
#
# - `TEN.txt` has 10 lines
# - `HUNDRED.txt` has 100 lines
# - `THOUSAND.txt` has 1000 lines.
#
# For each of the sub-tasks, add a comment statement at the beginning of the code using the hash symbol '#' to indicate the sub-task the program code belongs to, for example:
#
# ```
# In [1] : # Task 2.1
#          Program code
#
#          Output:
# ```

# %% [markdown]
# **Task 2.1**
#
# Write a function `task2_1(filename)` that:
#
# - takes a string `filename` which represents the name of a text file
# - reads in the contents of the text file
# - returns the content as a list of integers. **[3]**
#
# Call your function `task2_1` with the file `TEN.txt`, printing the returned list and its length, using the following statements:
#
# ```
# result = task2_1('TEN.txt')
# print(result)
# print(len(result))
# ```
#
# **[2]**

# %%
# Task 2.1
def task2_1(filename):
    list_of_integers = []
    with open(filename, 'r') as file:    #with open automatically closes the file at the end
        for line in file:
            line = line.strip()
            list_of_integers.append(int(line))
        return list_of_integers

#main program
result = task2_1("data files for 2021\\data files\\TEN.txt")
print(result)
print(len(result))
# Out:
# [1636, 3555, 3006, 653, 1665, 3865, 1447, 2568, 619, 2029]
# 10

# %% [markdown]
# **Task 2.2**
#
# One method of sorting is the insertion sort.
#
# Write a function `task2_2(list_of_integers)` that:
#
# - takes a list of integers
# - implements an insertion sort algorithm
# - returns the sorted list of integers. **[5]**
#
# Call your function `task2_2` with the contents of the file `TEN.txt`, printing the returned list, for example, using the following statement:
#
# `print(task2_2(task2_1('TEN.txt')))` **[1]**

# %%
# Task 2.2
def task2_2(list_of_integers):
    for i in range(1, len(list_of_integers)):
        key = list_of_integers[i]
        j = i - 1
        while j>=0 and list_of_integers[j]>key:
            list_of_integers[j+1] = list_of_integers[j]
            j = j-1
        list_of_integers[j+1] = key
    return list_of_integers

#main program
print(task2_2(task2_1('data files for 2021\\data files\\TEN.txt')))
# Out:
# [619, 653, 1447, 1636, 1665, 2029, 2568, 3006, 3555, 3865]

# %% [markdown]
# **Task 2.3**
#
# Another method of sorting is the quicksort.
#
# Write a function `task2_3(list_of_integers)` that:
#
# - takes a list of integers
# - implements a quicksort algorithm
# - returns the sorted list of integers. **[7]**
#
# Call your function `task2_3` with the contents of the file `TEN.txt`, printing the returned list, for example, using the following statement:
#
# `print(task2_3(task2_1('TEN.txt')))` **[1]**

# %%
# Task 2.3
def task2_3(list_of_integers):
    if len(list_of_integers) <= 1:
        return list_of_integers
    pivot = list_of_integers[len(list_of_integers)//2]

    smaller = []
    larger = []
    same = []
    for item in list_of_integers:
        if item < pivot:
            smaller.append(item)
        elif item == pivot:
            same.append(item)
        elif item > pivot:
            larger.append(item)

    return task2_3(smaller)+same+task2_3(larger)


#main program
print(task2_3(task2_1('data files for 2021\\data files\\TEN.txt')))
# Out:
# [619, 653, 1447, 1636, 1665, 2029, 2568, 3006, 3555, 3865]

# %% [markdown]
# **Task 2.4**
#
# The `timeit` library is built into Python and can be used to time simple function calls. Example code is shown in `Task2_timing.py`. (The sample code assumes that it has access to the `task2_2` function.)
#
# Using the `timeit` module, or other evidence, and the three text files provided with this question, compare and contrast, including mention of orders of growth, the time complexity of the insertion sort and quicksort algorithms. **[5]**

# %%
# Task 2.4
import timeit
'''
t1000 = task2_1('THOUSAND.txt')
# use the timeit function to call the task2_2(li) function with the 1000 integer list, run this just once 
time1000 = timeit.timeit(lambda: task2_2(t1000), number=1)
# print out the time, in seconds
print(time1000)
'''
count = 0
for file in ['data files for 2021\\data files\\TEN.txt', 'data files for 2021\\data files\\HUNDRED.txt', 'data files for 2021\\data files\\THOUSAND.txt']:
    data =  task2_1(file)   #convert file into list
    insertion_timing = timeit.timeit(lambda: task2_2(data), number=1)
    quicksort_timing = timeit.timeit(lambda: task2_3(data), number=1)
    length = ["TEN.txt","HUNDRED.txt","THOUSAND.txt"]
    print(f"File {length[count]} with {len(data)} integers, insertion sort took: {insertion_timing}s to sort the data")
    print(f"File {length[count]} with {len(data)} integers, quicksort took: {quicksort_timing}s to sort the data")
    count += 1
# Out:
# File TEN.txt with 10 integers, insertion sort took: 2.029999996011611e-05s to sort the data
# File TEN.txt with 10 integers, quicksort took: 2.6299999944967567e-05s to sort the data
# File HUNDRED.txt with 100 integers, insertion sort took: 0.0010608999999703883s to sort the data
# File HUNDRED.txt with 100 integers, quicksort took: 0.0003073999999969601s to sort the data
# File THOUSAND.txt with 1000 integers, insertion sort took: 0.08495210000000952s to sort the data
# File THOUSAND.txt with 1000 integers, quicksort took: 0.0012275000000272485s to sort the data

# %% [markdown]
# Save your Jupyter notebook for Task 2.
